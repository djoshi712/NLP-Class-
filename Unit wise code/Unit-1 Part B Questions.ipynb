# %% [markdown]
# ---Practice questions---
#
# https://www.w3resource.com/python-exercises/nltk/corpus-index.php

# %% [markdown]
# ## Stemming
# Stemming is a natural language processing technique that lowers inflection in words to their root forms, hence aiding in the preprocessing of text, words, and documents for text normalization.
# ### Why Stemming is Important?
# As previously stated, the English language has several variants of a single term. The presence of these variances in a text corpus results in data redundancy when developing NLP or machine learning models. Such models may be ineffective.
#
# To build a robust model, it is essential to normalize text by removing repetition and transforming words to their base form through stemming.
#
# ### Application of Stemming
# In information retrieval, text mining SEOs, Web search results, indexing, tagging systems, and word analysis, stemming is employed. For instance, a Google search for prediction and predicted returns comparable results.

# %% [markdown]
# ## Types (Imp)
# https://www.analyticsvidhya.com/blog/2021/11/an-introduction-to-stemming-in-natural-language-processing/

# %%
from nltk.stem import PorterStemmer, SnowballStemmer, LancasterStemmer, RegexpStemmer
porter = PorterStemmer()
lancaster = LancasterStemmer()
snowball = SnowballStemmer(language='english')
regexp = RegexpStemmer('ing$|s$|e$|able$', min=4)

# %%
word_list = ["friend", "friendship", "friends", "friendships"]
print("{0:20}{1:20}{2:20}{3:30}{4:40}".format("Word","Porter Stemmer","Snowball Stemmer","Lancaster Stemmer",'Regexp Stemmer'))
for word in word_list:
    print("{0:20}{1:20}{2:20}{3:30}{4:40}".format(word,porter.stem(word),snowball.stem(word),lancaster.stem(word),regexp.stem(word)))
# Out:
# Word                Porter Stemmer      Snowball Stemmer    Lancaster Stemmer             Regexp Stemmer
# friend              friend              friend              friend                        friend
# friendship          friendship          friendship          friend                        friendship
# friends             friend              friend              friend                        friend
# friendships         friendship          friendship          friend                        friendship

# %% [markdown]
# ## How is Lemmatization different from Stemming
# In stemming, a part of the word is just chopped off at the tail end to arrive at the stem of the word. There are definitely different algorithms used to find out how many characters have to be chopped off, but the algorithms don’t actually know the meaning of the word in the language it belongs to. In lemmatization, on the other hand, the algorithms have this knowledge. In fact, you can even say that these algorithms refer a dictionary to understand the meaning of the word before reducing it to its root word, or lemma.
#
# ### Advantages and Disadvantages of Lemmatization
# As you could probably tell by now, the obvious advantage of lemmatization is that it is more accurate. So if you’re dealing with an NLP application such as a chat bot or a virtual assistant where understanding the meaning of the dialogue is crucial, lemmatization would be useful. But this accuracy comes at a cost.
#
# Because lemmatization involves deriving the meaning of a word from something like a dictionary, it’s very time consuming. So most lemmatization algorithms are slower compared to their stemming counterparts. There is also a computation overhead for lemmatization.
#
#
# Examples of lemmatization:
#
# -> rocks : rock
#
# -> corpora : corpus
#
# -> better : good
#
#
# One major difference with stemming is that lemmatize takes a part of speech parameter, “pos” If not supplied, the default is “noun.”
#
# https://towardsdatascience.com/lemmatization-in-natural-language-processing-nlp-and-machine-learning-a4416f69a7b6

# %%
from nltk.stem import WordNetLemmatizer
  
lemmatizer = WordNetLemmatizer()
  
print("rocks :", lemmatizer.lemmatize("rocks"))
print("corpora :", lemmatizer.lemmatize("corpora"))
  
# a denotes adjective in "pos"
print("better :", lemmatizer.lemmatize("better", pos ="a"))
# Out:
# rocks : rock
# corpora : corpus
# better : good

# %%
# Write a Python NLTK program to get a list of common stop words in various languages in Python.
from nltk.corpus import stopwords
print (stopwords.fileids())
# Out:
# ['arabic', 'azerbaijani', 'basque', 'bengali', 'catalan', 'chinese', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hinglish', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'turkish']

# %%
# Write a Python NLTK program to check the list of stopwords in various languages.
from nltk.corpus import stopwords
result = set(stopwords.words('english'))
print("List of stopwords in English:")
print(result)
print("\nList of stopwords in Arabic:")
result = set(stopwords.words('arabic'))
print(result)
print("\nList of stopwords in Azerbaijani:")
result = set(stopwords.words('azerbaijani'))
print(result)
print("\nList of stopwords in Danish:")
result = set(stopwords.words('danish'))
print(result)
print("\nList of stopwords in Dutch:")
result = set(stopwords.words('dutch'))
print(result)
print("\nList of stopwords in Finnish:")
result = set(stopwords.words('finnish'))
print(result)
print("\nList of stopwords in French:")
result = set(stopwords.words('french'))
print(result)
print("\nList of stopwords in German:")
result = set(stopwords.words('german'))
print(result)
print("\nList of stopwords in Greek:")
result = set(stopwords.words('greek'))
print(result)
print("\nList of stopwords in Hungarian:")
result = set(stopwords.words('hungarian'))
print(result)
print("\nList of stopwords in Indonesian:")
result = set(stopwords.words('indonesian'))
print(result)
print("\nList of stopwords in Italian:")
result = set(stopwords.words('italian'))
print(result)
print("\nList of stopwords in Kazakh:")
result = set(stopwords.words('kazakh'))
print(result)
print("\nList of stopwords in Nepali:")
result = set(stopwords.words('nepali'))
print(result)
print("\nList of stopwords in Norwegian:")
result = set(stopwords.words('norwegian'))
print(result)
print("\nList of stopwords in Portuguese:")
result = set(stopwords.words('portuguese'))
print(result)
print("\nList of stopwords in Romanian:")
result = set(stopwords.words('romanian'))
print(result)
print("\nList of stopwords in Russian:")
result = set(stopwords.words('russian'))
print(result)
print("\nList of stopwords in Spanish:")
result = set(stopwords.words('spanish'))
print(result)
print("\nList of stopwords in Swedish:")
result = set(stopwords.words('swedish'))
print(result)
print("\nList of stopwords in Turkish:")
result = set(stopwords.words('turkish'))
print(result)
# Out:
# List of stopwords in English:
# {'didn', 'had', 'yours', 'or', 'no', 'should', "wouldn't", 'o', 'has', 'all', "couldn't", 'shan', "shouldn't", 'once', 'ourselves', 'for', 'd', 'most', 'him', 'itself', 'as', 'off', 'too', "hasn't", 'on', 'do', 'his', 'being', 'having', 'about', 'have', 'be', 'own', 'themselves', 'of', 'll', 'not', 'who', 'those', 't', 'some', 'ma', 'an', 'hadn', 'how', 'hasn', 'mightn', 'at', 'm', "wasn't", 'nor', 'whom', "don't", 'was', 'above', 'himself', 'yourself', 'because', 'y', 'its', 'through', 'are', 'me', "hadn't", 'your', 'while', 'does', 'again', 'myself', "weren't", 'a', 'during', 'is', 'and', 'doing', 'more', 'between', 'needn', 'so', 'than', 'won', "doesn't", "it's", 'below', 'out', 'isn', "mustn't", 'few', 'yourselves', 've', "she's", 'you', 'hers', 'such', 'mustn', 'from', 'did', 'doesn', 'both', "aren't", 'here', 'i', 'there', "needn't", 'now', 'her', 'if', 'aren', 'were', 'very', "you'd", 'down', "isn't", 'any', "you're", 'am', 'by', "won't", 'theirs', 'she', 'other', 'herself', 'then', 'them', 'what', 'we', 'after', 'but', 'couldn', 're', 'it', 'wouldn', 'their', "mightn't", 'can', 'shouldn', 'only', 'our', 'the', 'over', 'ours', 'don', 'against', 'why', 'same', "you've", 'which', 'in', 'to', 'will', 'been', 'under', "didn't", "you'll", 'where', "haven't", 'he', 'up', 'just', 'before', 'with', "shan't", 'until', 'further', 'that', 'when', 'weren', "should've", 'haven', 'this', 'ain', 'they', "that'll", 'each', 's', 'these', 'my', 'wasn', 'into'}
#
# List of stopwords in Arabic:
# {'سبعة', 'آهٍ', 'غادر', 'لا سيما', 'شمال', 'تَيْنِ', 'لم', 'هلا', 'ذينك', 'هَؤلاء', 'حمٌ', 'ع', 'إنه', 'ب', 'أوه', 'ما برح', 'ذَيْنِ', 'إليكم', 'ثلاث', 'راح', 'غدا', 'ق', 'آهاً', 'له', 'أفريل', 'مما', 'الألى', 'رزق', 'أخبر', 'ساء', 'يورو', 'تانِك', 'بعض', 'عاد', 'لي', 'وإن', 'تجاه', 'تموز', 'حتى', 'وما', 'أربع', 'تين', 'لك', 'ومن', 'إمّا', 'ما انفك', 'حيثما', 'لعل', 'كأيّن', 'بطآن', 'يفعلان', 'لنا', 'لكنَّ', 'لهما', 'عين', 'أوت', 'ف', 'ذوا', 'ليس', 'هَاتانِ', 'لكيلا', 'أيّان', 'أمّا', 'أسكن', 'هؤلاء', 'إيهٍ', 'نَخْ', 'بس', 'كأنّ', 'أم', 'تاسع', 'إليكما', 'عشرة', 'خ', 'ستمئة', 'يفعلون', 'كانون', 'نا', 'بكن', 'ى', 'تارة', 'والذي', 'هذي', 'فبراير', 'ذواتي', 'سقى', 'اللذان', 'حبذا', 'هَيْهات', 'أنتِ', 'كأي', 'حسب', 'مادام', 'أول', 'نَّ', 'أعلم', 'كلما', 'أضحى', 'وهب', 'ذيت', 'أنتما', 'لا', 'لولا', 'خامس', 'سين', 'ألف', 'ياء', 'إياكما', 'خلافا', 'حمو', 'سبعون', 'أولاء', 'عامة', 'تفعلين', 'أيها', 'بهم', 'كذا', 'كرب', 'كيفما', 'ثماني', 'جيم', 'كليكما', 'رويدك', 'طفق', 'لكن', 'فو', 'نون', 'أوّهْ', 'ذانك', 'واحد', 'اللتان', 'قام', 'أبو', 'آه', 'ثلاثمائة', 'بسّ', 'تسعمائة', 'ثان', 'هذين', 'أربعة', 'أكتوبر', 'ض', 'فلا', 'هيهات', 'لعلَّ', 'تلكم', 'ألفى', 'ها', 'جعل', 'لات', 'ابتدأ', 'اثنان', 'خلا', 'ثمان', 'إذاً', 'تاء', 'بَسْ', 'ي', 'تسعين', 'ستمائة', 'إيانا', 'ريث', 'إياه', 'مرّة', 'فيها', 'حادي', 'ا', 'نيسان', 'حرى', 'إلى', 'كِخ', 'ممن', 'ن', 'وجد', 'كن', 'ذهب', 'أُفٍّ', 'قاطبة', 'هي', 'إنما', 'كأيّ', 'انبرى', 'مائة', 'يوان', 'هَذانِ', 'تلك', 'بي', 'أهلا', 'إذن', 'أخو', 'ست', 'كيف', 'هَاتَيْنِ', 'مع', 'لوما', 'إذا', 'جويلية', 'ثمّ', 'هما', 'بهن', 'حبيب', 'تخذ', 'ثلاثة', 'إليكنّ', 'باء', 'صهْ', 'ذلكما', 'أنشأ', 'عليه', 'ليست', 'هاتان', 'حيَّ', 'أربعاء', 'ثمانون', 'أبٌ', 'سرعان', 'ولا', 'إنَّ', 'ستة', 'ورد', 'ذانِ', 'دولار', 'أرى', 'إى', 'لما', 'كيت', 'س', 'شبه', 'أبدا', 'هو', 'خبَّر', 'سوف', 'نفس', 'لها', 'ثاني', 'درى', 'علم', 'جنيه', 'بَلْهَ', 'كسا', 'أيا', 'استحال', 'أعطى', 'اللذين', 'هَذِي', 'بكم', 'فيم', 'تسع', 'ش', 'أكثر', 'تلكما', 'سبعمئة', 'أخذ', 'كي', 'أيلول', 'رأى', 'قبل', 'أيار', 'ظ', 'أما', 'ضاد', 'زاي', 'أنا', 'أنتم', 'غير', 'هللة', 'شباط', 'ل', 'بات', 'خمسين', 'ط', 'سمعا', 'مئة', 'إحدى', 'وهو', 'هاكَ', 'سنتيم', 'بمن', 'اثنين', 'سوى', 'أخٌ', 'قد', 'ذال', 'إيه', 'من', 'لدن', 'قلما', 'إليك', 'ثمانية', 'تحت', 'لسنا', 'يمين', 'شَتَّانَ', 'صباح', 'عشرين', 'بكما', 'عيانا', 'فمن', 'هيت', 'اثنا', 'أين', 'ذلكن', 'نبَّا', 'سبعمائة', 'ديسمبر', 'يناير', 'هَجْ', 'إنا', 'إلّا', 'نوفمبر', 'بماذا', 'إياي', 'ما', 'يوليو', 'لو', 'م', 'لستما', 'لئن', 'مذ', 'إياكم', 'ضحوة', 'عجبا', 'عشر', 'أجل', 'اللائي', 'ظنَّ', 'ثلاثون', 'أنت', 'لستن', 'هكذا', 'د', 'إياك', 'أصبح', 'ت', 'ارتدّ', 'تبدّل', 'متى', 'لهم', 'اتخذ', 'لام', 'كذلك', 'ثمة', 'آها', 'همزة', 'أطعم', 'أينما', 'هيا', 'فإن', 'عما', 'مكانكما', 'منها', 'انقلب', 'كان', 'أي', 'ذو', 'بك', 'غالبا', 'مليم', 'بها', 'ذان', 'لكي', 'تشرين', 'أنبأ', 'أنتن', 'ثم', 'أنًّ', 'بؤسا', 'هناك', 'عل', 'درهم', 'ءَ', 'كلّما', 'ذلك', 'اربعون', 'جير', 'فيه', 'مازال', 'أمامك', 'أولالك', 'مئتان', 'بلى', 'إليكَ', 'كليهما', 'أفٍّ', 'صار', 'هَذَيْنِ', 'آمينَ', 'بل', 'آب', 'أبريل', 'واهاً', 'ثمانمئة', 'طاق', 'أف', 'زود', 'كل', 'هذه', 'ذِه', 'مثل', 'تلقاء', 'إياكن', 'ماي', 'أى', 'هيّا', 'دونك', 'صراحة', 'آناء', 'كثيرا', 'إذما', 'رجع', 'أقبل', 'خمسون', 'لاسيما', 'شرع', 'دال', 'أربعمئة', 'اللاتي', 'فيفري', 'ريال', 'سبع', 'كأين', 'أربعمائة', 'ح', 'ذِي', 'دينار', 'حمدا', 'لبيك', 'اربعين', 'أيضا', 'سبت', 'ثلاثاء', 'آ', 'فوق', 'به', 'هن', 'أحد', 'سبحان', 'عدَّ', 'أيّ', 'أمامكَ', 'ج', 'أنّى', 'ثامن', 'عليك', 'التي', 'اللتيا', 'فيما', 'هاك', 'فلس', 'تسعون', 'ّأيّان', 'طرا', 'تعلَّم', 'لعمر', 'آي', 'ثلاثمئة', 'ء', 'قاف', 'إزاء', 'لكم', 'آذار', 'خاصة', 'بين', 'إن', 'حاء', 'ليت', 'بخٍ', 'فلان', 'إياهم', 'تفعلان', 'أفعل به', 'زعم', 'بعدا', 'سبتمبر', 'بهما', 'مافتئ', 'ولو', 'بغتة', 'راء', 'إياهما', 'ظلّ', 'فاء', 'ه', 'عسى', 'شتانَ', 'مارس', 'صدقا', 'فضلا', 'حقا', 'طَق', 'هنالك', 'جوان', 'ين', 'هبّ', 'هَذا', 'ليسا', 'الألاء', 'ثمانين', 'أو', 'يا', 'عَدَسْ', 'ز', 'هل', 'عند', 'تانِ', 'ظاء', 'مكانَك', 'كلا', 'ولكن', 'مساء', 'إي', 'نحن', 'ل ...
#
# List of stopwords in Azerbaijani:
# {'yalnız', 'sadəcə', 'altmış', 'məhz', 'o', 'lakin', 'iyirmi', 'nəhayət', 'həmin', 'yoxdur', 'bizim', 'xan', 'çox', 'sən', 'qədər', 'ü', 'isə', 'üçün', 'olaraq', 'yaxşı', 'on', 'ya', 'onu', 'nə', 'deyil', 'dəqiqə', 'olmaz', 'və', 'of', 'təəssüf', 'xeyr', 'də', 'həmişə', 'əslində', 'sizin', 'ha', 'biraz', 'edir', 'onsuzda', 'et', 'əlbəttə', 'olur', 'dir', 'idi', 'saniyə', 'olsun', 'elə', 'da', 'bəy', 'olmadı', 'saat', 'siz', 'sonra', 'səkkiz', 'oradan', 'iki', 'zaman', 'bütün', 'bu', 'dən', 'bəzi', 'əgər', 'üç', 'yüz', 'mirşey', 'ə', 'səksən', 'edən', 'doqsan', 'artıq', 'dörd', 'gilə', 'xanım', 'qarşı', 'il', 'a', 'ondan', 'doqquz', 'yəni', 'qırx', 'kimə', 'heç', 'ən', 'ad', 'onlar', 'bunların', 'həm', 'biri', 'cu', 'olduğu', 'etdi', 'faiz', 'yoxsa', 'bunu', 'mən', 'hər', 'sizlər', 'oldu', 'bəzən', 'daha', 'bilər', 'buna', 'ildə', 'arasında', 'obirisi', 'öz', 'otuz', 'indi', 'haqqında', 'belə', 'ı', 'cı', 'hə', 'dək', 'biz', 'kim', 'sənə', 'bax', 'olar', 'əlli', 'lap', 'bunun', 'ci', 'yox', 'çünki', 'özü', 'yenə', 'səhv', 'cü', 'ilə', 'bəli', 'harada', 'etmək', 'bizlər', 'onlardan', 'istifadə', 'ay', 'bəlkə', 'bir', 'bundan', 'etmə', 'sənin', 'niyə', 'in', 'dedi', 'altı', 'görə', 'mənə', 'onun', 'onların ', 'ona', 'düz', 'ilk', 'amma', 'buradan', 'kimi', 'birşey', 'az', 'olan', 'yeddi', 'olmuşdur', 'yetmiş', 'ki', 'var', 'beş'}
#
# List of stopwords in Danish:
# {'blev', 'vil', 'os', 'alt', 'ind', 'ham', 'fra', 'for', 'havde', 'thi', 'disse', 'vi', 'når', 'skulle', 'på', 'til', 'ville', 'deres', 'have', 'anden', 'din', 'hvis', 'og', 'mange', 'mit', 'meget', 'af', 'et', 'om', 'at', 'også', 'selv', 'da', 'jer', 'været', 'hvor', 'er', 'være', 'har', 'han', 'hos', 'min', 'dem', 'skal', 'bliver', 'blive', 'ad', 'hans', 'noget', 'nogle', 'mine', 'alle', 'jeg', 'i', 'her', 'en', 'de', 'sig', 'sit', 'hendes', 'sine', 'dog', 'hende', 'dig', 'dette', 'ikke', 'kunne', 'op', 'sådan', 'nu', 'den', 'eller', 'mig', 'hun', 'med', 'jo', 'ud', 'over', 'end', 'men', 'du', 'som', 'vor', 'hvad', 'denne', 'der', 'efter', 'under', 'mod', 'det', 'ned', 'man', 'sin', 'var'}
#
# List of stopwords in Dutch:
# {'had', 'maar', 'zal', 'met', 'want', 'onder', 'ons', 'ik', 'aan', 'wezen', 'dit', 'deze', 'reeds', 'geweest', 'kunnen', 'kan', 'eens', 'heb', 'of', 'wat', 'na', 'een', 'zijn', 'om', 'hem', 'te', 'was', 'daar', 'voor', 'wil', 'er', 'toch', 'zo', 'me', 'je', 'hebben', 'dus', 'dat', 'is', 'tegen', 'van', 'veel', 'zich', 'het', 'uw', 'door', 'ja', 'tot', 'bij', 'andere', 'nog', 'zonder', 'uit', 'hier', 'alles', 'worden', 'kon', 'mijn', 'zij', 'en', 'de', 'naar', 'omdat', 'werd', 'doen', 'iemand', 'meer', 'hij', 'moet', 'op', 'als', 'ge', 'nu', 'ook', 'geen', 'hun', 'niet', 'wie', 'haar', 'waren', 'iets', 'altijd', 'over', 'wordt', 'men', 'zou', 'heeft', 'in', 'doch', 'der', 'ben', 'al', 'die', 'mij', 'toen', 'hoe', 'niets', 'dan', 'u', 'zelf', 'ze'}
#
# List of stopwords in Finnish:
# {'tuosta', 'keissä', 'meille', 'hänestä', 'meidät', 'joista', 'miltä', 'näinä', 'olin', 'keneltä', 'ne', 'sinun', 'ei', 'sinulta', 'ovat', 'tuo', 'millä', 'tai', 'heille', 'keitä', 'yli', 'nuo', 'noille', 'jonka', 'eivät', 'sinulla', 'tänä', 'kenen', 'teitä', 'mutta', 'kenelle', 'vaan', 'on', 'minä', 'olitte', 'näissä', 'nämä', 'joissa', 'kenellä', 'sinut', 'tälle', 'keihin', 'näistä', 'noina', 'hänessä', 'tuona', 'minkä', 'näihin', 'keneen', 'niihin', 'missä', 'olisi', 'näiksi', 'siitä', 'et', 'joilta', 'mukaan', 'noihin', 'näillä', 'keistä', 'sinua', 'te', 'sinussa', 'sitä', 'näille', 'noista', 'noilla', 'mitä', 'joiksi', 'heihin', 'hän', 'kenessä', 'vai', 'kuin', 'jota', 'kun', 'miksi', 'jossa', 'joita', 'kuka', 'teistä', 'tallä', 'tuoksi', 'minussa', 'minua', 'olisitte', 'nyt', 'me', 'ette', 'heitä', 'joka', 'mille', 'minulle', 'olisin', 'näitä', 'keneksi', 'joksi', 'sinuun', 'näiden', 'keinä', 'meitä', 'teillä', 'että', 'häntä', 'niinä', 'keiden', 'olemme', 'tähän', 'kanssa', 'tuohon', 'sen', 'mistä', 'mihin', 'siihen', 'minun', 'ja', 'niiksi', 'heistä', 'joille', 'heidät', 'noiksi', 'kenenä', 'heissä', 'sinulle', 'tässä', 'hänet', 'meissä', 'tuotä', 'jos', 'meidän', 'olivat', 'jolta', 'keiltä', 'jona', 'noilta', 'ketä', 'häneen', 'joiden', 'siksi', 'johon', 'jotka', 'olit', 'siinä', 'ollut', 'en', 'heillä', 'itse', 'tämän', 'täksi', 'emme', 'sinä', 'tuolle', 'poikki', 'hänellä', 'niissä', 'minuun', 'tuolla', 'olisit', 'hänen', 'joilla', 'olen', 'olisivat', 'heiltä', 'tuolta', 'siltä', 'keiksi', 'kenet', 'heidän', 'tästä', 'sekä', 'teiltä', 'teille', 'joina', 'niillä', 'olette', 'olla', 'tältä', 'minulta', 'mitkä', 'jolla', 'meiltä', 'tätä', 'tuon', 'minulla', 'se', 'näiltä', 'niistä', 'minut', 'niiltä', 'meihin', 'olisimme', 'oli', 'ole', 'olleet', 'tämä', 'teidät', 'meistä', 'keille', 'niitä', 'noin', 'vaikka', 'keillä', 'niin', 'koska', 'hänelle', 'teissä', 'minusta', 'niille', 'häneltä', 'jolle', 'sinusta', 'he', 'kenestä', 'teihin', 'joihin', 'ketkä', 'meillä', 'noiden', 'niiden', 'noita', 'olimme', 'tuossa', 'sillä', 'olet', 'noissa', 'teidän', 'mikä', 'sille', 'josta'}
#
# List of stopwords in French:
# {'aura', 'à', 'tes', 'par', 'notre', 'étées', 'fussions', 'ne', 'd', 'fût', 'toi', 'fussiez', 'auraient', 'as', 'sommes', 'étants', 'nos', 'on', 'aurait', 'aies', 'ayantes', 'étions', 'n', 'ce', 'serions', 'ta', 'pas', 'ils', 'eurent', 't', 'eu', 'ayez', 'ma', 'fûtes', 'ayante', 'ont', 'eux', 'furent', 'eussiez', 'pour', 'avons', 'c', 'auriez', 'des', 'et', 'mes', 'étaient', 'ou', 'soyons', 'm', 'soyez', 'fusses', 'te', 'ton', 'aie', 'fussent', 'y', 'eut', 'seriez', 'avais', 'me', 'aurions', 'ayants', 'étante', 'je', 'votre', 'avait', 'vous', 'vos', 'il', 'soient', 'seras', 'auront', 'aurez', 'suis', 'étée', 'ces', 'les', 'étés', 'eusse', 'êtes', 'étais', 'tu', 'eus', 'est', 'fus', 'fûmes', 'ai', 'es', 'soit', 'avez', 'qui', 'sont', 'en', 'de', 'au', 'avions', 'serait', 'sur', 'eues', 'eussent', 'aurais', 'eûmes', 'serez', 'un', 'étantes', 'que', 'aient', 'serais', 'l', 'moi', 'aurons', 'auras', 'ait', 'leur', 'seraient', 'se', 'mais', 'le', 'fut', 'eussions', 'ayant', 'j', 'sois', 'eûtes', 'qu', 'la', 'sa', 'son', 'serons', 'du', 'était', 'lui', 'serai', 'aux', 'fusse', 'dans', 'étiez', 'avaient', 'avec', 'aviez', 'une', 'eût', 'sera', 'été', 'aurai', 'elle', 'seront', 'eue', 'eusses', 's', 'même', 'mon', 'étant', 'ses', 'ayons', 'nous'}
#
# List of stopwords in German:
# {'allen', 'keinem', 'mein', 'und', 'unserem', 'von', 'anderes', 'welcher', 'auf', 'sonst', 'diesem', 'einige', 'seine', 'dazu', 'für', 'denselben', 'sind', 'seiner', 'dieser', 'jenen', 'euren', 'einmal', 'demselben', 'wirst', 'anderem', 'habe', 'solchem', 'welche', 'um', 'ihrer', 'ander', 'mich', 'derer', 'anderen', 'an', 'zum', 'allem', 'ihrem', 'nun', 'ich', 'viel', 'hatte', 'einem', 'dass', 'machen', 'mit', 'gewesen', 'meinen', 'ihren', 'eurem', 'des', 'keine', 'können', 'nur', 'ein', 'während', 'dir', 'jedes', 'da', 'was', 'manchem', 'dort', 'ihres', 'jedem', 'würden', 'er', 'muss', 'denn', 'sein', 'solchen', 'einigem', 'mir', 'einiger', 'meiner', 'bin', 'desselben', 'unseres', 'war', 'weg', 'ihnen', 'solcher', 'welches', 'dem', 'durch', 'jeder', 'einen', 'eines', 'wird', 'diesen', 'anders', 'bis', 'wenn', 'ihn', 'dessen', 'meine', 'dieses', 'würde', 'derselben', 'so', 'weiter', 'euch', 'das', 'hat', 'solche', 'mancher', 'meinem', 'sollte', 'wo', 'uns', 'euer', 'hin', 'sie', 'andere', 'eure', 'ihr', 'jener', 'warst', 'damit', 'seinem', 'deiner', 'dann', 'ihm', 'keiner', 'zu', 'ins', 'hier', 'eurer', 'eures', 'es', 'solches', 'alle', 'ihre', 'alles', 'anderm', 'einigen', 'werden', 'könnte', 'indem', 'oder', 'zwischen', 'dieselbe', 'bei', 'aber', 'noch', 'eine', 'anderer', 'sondern', 'wollen', 'hatten', 'dasselbe', 'jede', 'daß', 'andern', 'über', 'dich', 'welchem', 'vom', 'hinter', 'diese', 'jetzt', 'am', 'gegen', 'sich', 'meines', 'deinen', 'keinen', 'selbst', 'manche', 'nichts', 'einig', 'bist', 'als', 'derselbe', 'weil', 'den', 'sehr', 'wollte', 'einer', 'einiges', 'auch', 'also', 'manches', 'welchen', 'musste', 'deinem', 'ob', 'wie', 'jeden', 'waren', 'wieder', 'anderr', 'kann', 'deine', 'nicht', 'du', 'aller', 'vor', 'unter', 'soll', 'unser', 'doch', 'haben', 'in', 'der', 'dies', 'seinen', 'dieselben', 'will', 'jene', 'manchen', 'aus', 'die', 'im', 'ist', 'zwar', 'hab', 'seines', 'werde', 'kein', 'jenes', 'man', 'ohne', 'jenem', 'wir', 'nach', 'keines', 'zur', 'unsere', 'dein', 'deines', 'etwas', 'unseren'}
#
# List of stopwords in Greek:
# {'ποιο', 'τήν', 'τησ', 'ποῦ', 'τὰ', 'αυτη', 'ειναι', 'δὴ', 'τινα', 'ἐὰν', 'μὲν', 'γοῦν', 'για', 'ἔτι', 'οὖν', 'οὐκ', 'των', 'τῶν', 'παρα', 'δέ', 'ἅμα', 'οὔτε', 'μέν', 'που', 'γάρ', 'ποιεσ', 'εκεινων', 'τότε', 'ὃν', 'ἀλλ’', 'ὑπὲρ', 'ἀπ', 'ὅδε', 'οὐδεὶς', 'γα^', 'γα', 'ὃς', 'τοιοῦτοσ', 'ειμαστε', 'κατα', 'μετα', 'οὕτως', 'ἢ', "δ'", 'δαί', 'ποιοσ', 'ὅθεν', 'ὅσ', 'εἴτε', 'ἄν', 'εκεινα', 'μὴ', 'κατὰ', 'οἷς', 'ποιων', 'αλλα', 'δαίσ', 'εἴμι', 'ποτε', 'και', 'τοὺς', 'τοῦ', 'τά', 'τὰς', 'ἀφ', 'εκεινο', 'ἣ', 'σε', 'αν', 'ποιοι', 'ἧς', 'διά', 'ἐγὼ', 'ὑμόσ', 'ὑπό', 'ἐφ', 'μετ', 'τις', 'ἥ', 'ὑπέρ', 'οὓς', 'ποιουσ', 'ᾧ', 'μην', 'οὗτοσ', 'τῷ', 'ὡσ', 'ἐγώ', 'ὥστε', 'μη', 'καθ', 'οσο', 'ὦ', 'εκεινη', 'μή', 'μετά', 'οτι', 'δ’', 'οὐδὲν', 'πρὸ', 'του', 'ἀλλὰ', 'επι', 'ἃ', 'ἄλλοσ', 'ἤ', 'ομωσ', 'ἑαυτοῦ', 'αὐτόσ', 'να', 'αυτοσ', 'καί', 'τον', 'ἵνα', "ἀλλ'", 'σύ', 'η', 'οὕτω', 'αὐτὸς', 'αυτων', 'περί', 'στην', 'τοτε', 'μεθ', 'ἡ', 'σύν', 'ἄρα', 'ἀλλά', 'τί', 'ὑπ', 'την', 'πρὸς', 'ισωσ', 'οὐχὶ', 'τὸν', 'ἀπό', 'ὥς', 'οὐδείσ', 'ειμαι', 'ὅ', 'τούσ', 'πως', 'τόν', 'τε', 'πρόσ', 'στη', 'παρά', 'οἱ', 'εἰς', 'τισ', 'μα', 'παρ', 'μὴν', 'οὐ', 'με', 'σὸς', 'τό', 'τοῖς', 'εἰμί', 'ταῖς', 'γὰρ', 'οὐδὲ', 'οπωσ', 'οὗτος', 'δαὶς', 'ἐμὸς', 'τοί', 'δή', 'κι', 'ὃ', 'τίσ', 'κἀν', 'οι', 'τι', 'τὴν', 'το', 'ὁ', 'αντι', 'κἂν', 'ενω', 'εἴ', 'θα', 'εἰ', 'ὅπερ', 'οὐχ', 'ὅτι', 'σὺν', 'τῆς', 'ἐκ', 'παρὰ', 'εκεινεσ', 'απο', 'δε', 'καὶ', 'ωσ', 'μἐν', 'στο', 'ποια', 'τῆσ', 'διὰ', 'οὐδέ', 'εκεινουσ', 'ἂν', 'αἵ', 'αυτεσ', 'περὶ', 'οἳ', 'κ', 'σὺ', 'ἐάν', 'ἐστι', 'ὑπὸ', 'εἰσ', 'ο', 'καίτοι', 'εἰμὶ', 'ἐμόσ', 'τοιοῦτος', 'μετὰ', 'αυτοι', 'εκεινοσ', 'τα', 'στον', 'ὅστις', 'αἱ', 'πωσ', 'ἀπὸ', 'ὅς', 'τῇ', 'κατά', 'προσ', 'δεν', 'προ', "δι'", 'αυτο', 'οὐδ', 'εισαι', 'δαὶ', 'ἐπί', 'ειστε', 'ὡς', 'οὕτωσ', 'κατ', 'τίς', 'επ', 'τὸ', 'αἳ', 'οὗ', 'τοι', 'σόσ', 'αὖ', 'ἐν', 'αυτουσ', 'γε', 'εαν', 'ἐξ', 'ὅτε', 'ἄλλος', 'αυτα', 'ὅστισ', 'ἐπεὶ', 'μήτε', 'δὲ', 'ἐπὶ', 'εκεινοι'}
#
# List of stopwords in Hungarian:
# {'mikor', 'ezért', 'vissza', 'magát', 'nem', 'én', 'amit', 'valamint', 'újra', 'kellett', 'viszont', 'után', 'azon', 'ez', 'míg', 'ne', 'egy', 'õk', 'tovább', 'ebben', 'közül', 'most', 'nincs', 'emilyen', 'ugyanis', 'akkor', 'igen', 'pedig', 'amelyek', 'mellett', 'össze', 'éppen', 'mintha', 'nagyon', 'majd', 'be', 'jól', 'szinte', 'legalább', 'azután', 'között', 'bár', 'arról', 'egyetlen', 'jobban', 'semmi', 'vagy', 'ison', 'sem', 'amely', 'mit', 'azért', 'benne', 'el', 'ismét', 'sok', 'ennek', 'át', 'elõtt', 'néhány', 'már', 'azzal', 'e', 'keresztül', 'felé', 'belül', 'sokat', 'amelyet', 'amolyan', 'maga', 'vannak', 'milyen', 'ilyen', 'szemben', 'tehát', 'sokkal', 'valami', 'csak', 'és', 'mivel', 'egyes', 'voltak', 'nagy', 'teljes', 'cikk', 'a', 'ehhez', 'így', 'új', 'amelyeket', 'ilyenkor', 'õ', 'neki', 'utána', 'van', 'itt', 'lenni', 'ekkor', 'aztán', 'melyek', 'ahol', 'amelynek', 'mindent', 'nélkül', 'vagyis', 'legyen', 'lehet', 'aki', 'másik', 'lesz', 'jó', 'volt', 'néha', 'voltam', 'meg', 'illetve', 'voltunk', 'ezt', 'keressünk', 'ill', 'ahogy', 'hogyan', 'saját', 'miért', 'nekem', 'fel', 'továbbá', 'azonban', 'annak', 'de', 'ellen', 'kívül', 'olyan', 'eddig', 'rá', 'kell', 'még', 'ami', 'mindenki', 'akik', 'utolsó', 'ill.', 'egyre', 'volna', 'abban', 'amikor', 'ezen', 'számára', 'úgy', 'talán', 'amelyekben', 'több', 'lett', 'õket', 'való', 'erre', 'mint', 'nagyobb', 'hanem', 'azt', 'szerint', 'egyéb', 'általában', 'újabb', 'vele', 'ott', 'elég', 'egész', 'vagyok', 'alatt', 'elsõ', 'ezzel', 'mindig', 'lenne', 'által', 'lehetett', 'egyik', 'mert', 'cikkek', 'hiszen', 'ahhoz', 'arra', 'elõ', 'amíg', 'hogy', 'persze', 'mely', 'azok', 'elõször', 'ezek', 'az', 'minden', 'cikkeket', 'mi', 'más', 's', 'valaki', 'ki'}
#
# List of stopwords in Indonesian:
# {'tambah', 'seingat', 'sesekali', 'naik', 'sejauh', 'kira-kira', 'sepantasnyalah', 'toh', 'pantas', 'kok', 'setinggi', 'terus', 'punya', 'sekurang-kurangnya', 'mendapatkan', 'mendatangkan', 'seringnya', 'enggaknya', 'dikarenakan', 'seperti', 'masa', 'dimaksudnya', 'berkata', 'menunjukkan', 'tersampaikan', 'sesegera', 'jawab', 'terhadapnya', 'sendiri', 'sedangkan', 'seorang', 'kalaupun', 'padahal', 'kepada', 'menandaskan', 'begitupun', 'kepadanya', 'sudah', 'sampai', 'setiba', 'hanyalah', 'macam', 'masalahnya', 'menyeluruh', 'awalnya', 'sinilah', 'berkehendak', 'manalagi', 'berakhirlah', 'usah', 'agaknya', 'cukup', 'makin', 'selama-lamanya', 'bahkan', 'sejumlah', 'diperlukan', 'dulu', 'saling', 'memberikan', 'asal', 'kecil', 'diketahui', 'diperlihatkan', 'mengatakan', 'seluruh', 'ditanyakan', 'dimisalkan', 'dikatakan', 'masihkah', 'bersiap', 'diperkirakan', 'para', 'dijelaskannya', 'hanya', 'diakhirinya', 'mereka', 'seketika', 'pertama-tama', 'kesampaian', 'mulanya', 'seterusnya', 'begini', 'yakni', 'bermacam-macam', 'dua', 'awal', 'dengan', 'kelihatan', 'pak', 'sementara', 'hampir', 'wahai', 'diberikan', 'benarlah', 'merekalah', 'lamanya', 'betul', 'ujar', 'selama', 'sempat', 'apatah', 'seolah-olah', 'sekadarnya', 'masalah', 'diketahuinya', 'tampak', 'mempergunakan', 'pukul', 'mungkin', 'sekali', 'depan', 'dekat', 'meminta', 'belum', 'manakala', 'disinilah', 'diri', 'antara', 'berlangsung', 'memperkirakan', 'umum', 'adalah', 'diberi', 'pentingnya', 'menanya', 'belakangan', 'belakang', 'lalu', 'sesudah', 'atas', 'diungkapkan', 'berujar', 'entahlah', 'bertanya', 'digunakan', 'meyakini', 'dikerjakan', 'sebagian', 'sendirinya', 'semisal', 'sebagainya', 'besar', 'ataupun', 'jumlahnya', 'terdapat', 'suatu', 'berbagai', 'masing-masing', 'berawal', 'berlalu', 'termasuk', 'ia', 'mengerjakan', 'waktu', 'beri', 'berakhirnya', 'mendatang', 'adanya', 'menuju', 'kini', 'merasa', 'bersama-sama', 'kalaulah', 'dipunyai', 'kala', 'hari', 'disini', 'diminta', 'ibarat', 'meskipun', 'inginkan', 'akhiri', 'pula', 'sedemikian', 'kedua', 'akulah', 'bung', 'gunakan', 'serupa', 'tinggi', 'dialah', 'menanti-nanti', 'satu', 'hal', 'semuanya', 'jawaban', 'dipersoalkan', 'misal', 'akankah', 'itukah', 'olehnya', 'tanpa', 'tiba-tiba', 'andalah', 'teringat', 'terjadi', 'tidakkah', 'tegasnya', 'demi', 'setengah', 'keduanya', 'tandasnya', 'terdiri', 'sedang', 'disampaikan', 'amatlah', 'bolehkah', 'tetapi', 'sesudahnya', 'perlukah', 'terdahulu', 'dimintai', 'berlainan', 'antar', 'tahun', 'terutama', 'demikianlah', 'karena', 'jadilah', 'pada', 'sebabnya', 'dipergunakan', 'keluar', 'percuma', 'harusnya', 'mempersoalkan', 'lagian', 'mengungkapkan', 'seolah', 'didapat', 'menginginkan', 'sedikit', 'nyatanya', 'datang', 'meski', 'dilihat', 'tanyanya', 'apakah', 'telah', 'kamilah', 'dimungkinkan', 'hendaklah', 'kelihatannya', 'kapankah', 'maupun', 'memisalkan', 'untuk', 'bagian', 'ikut', 'sering', 'segala', 'beginian', 'pernah', 'setempat', 'dituturkan', 'mana', 'saya', 'mengingat', 'bertutur', 'bagi', 'maka', 'tambahnya', 'nanti', 'kelima', 'mengucapkannya', 'bagai', 'sebaik-baiknya', 'ditunjuki', 'berlebihan', 'panjang', 'sebaik', 'sini', 'melihatnya', 'tampaknya', 'sebaiknya', 'tahu', 'mengibaratkannya', 'baru', 'apaan', 'kiranya', 'sepihak', 'dikira', 'turut', 'tiba', 'malah', 'sekarang', 'hendak', 'guna', 'kamulah', 'ibaratnya', 'mula', 'sebelumnya', 'diingatkan', 'sewaktu', 'nyaris', 'lain', 'semakin', 'semampunya', 'pihaknya', 'sebenarnya', 'enggak', 'memang', 'memihak', 'kira', 'tepat', 'benarkah', 'jelasnya', 'berkeinginan', 'bagaimanapun', 'di', 'tidak', 'beginikah', 'dituturkannya', 'demikian', 'jangan', 'berapa', 'siapakah', 'pertanyakan', 'seharusnya', 'disebutkannya', 'mulailah', 'melakukan', 'atau', 'sekadar', 'menghendaki', 'pertanyaan', 'dimaksud', 'adapun', 'bertanya-tanya', 'sekalian', 'berapapun', 'rata', 'menanti', 'tapi', 'berakhir', 'mulai', 'lima', 'berdatangan', 'bawah', 'tak', 'wong', 'sebutnya', 'menaiki', 'mungkinkah', 'minta', 'sekitar', 'b ...
#
# List of stopwords in Italian:
# {'vostri', 'uno', 'avendo', 'fu', 'fossimo', 'o', 'tue', 'eravate', 'all', 'facciano', 'staresti', 'cui', 'abbia', 'stavano', 'dai', 'ne', 'nell', 'questi', 'tuo', 'facciamo', 'loro', 'stai', 'farebbero', 'sulla', 'stessimo', 'vi', 'avete', 'avresti', 'facessero', 'sua', 'io', 'starò', 'noi', 'feci', 'più', 'faccio', 'furono', 'degli', 'avrete', 'fareste', 'avreste', 'quelle', 'quanti', 'facessi', 'della', 'ma', 'dalle', 'stesse', 'farebbe', 'facendo', 'ha', 'tutti', 'avrebbe', 'sarei', 'facciate', 'del', 'vostro', 'c', 'sarete', 'ti', 'aveva', 'farà', 'degl', 'siate', 'faccia', 'stesti', 'questo', 'delle', 'stessi', 'coi', 'starà', 'da', 'alla', 'una', 'e', 'agl', 'negli', 'sareste', 'avevamo', 'fosse', 'avrà', 'faresti', 'avuto', 'nei', 'nostra', 'siete', 'staremo', 'avuti', 'fece', 'voi', 'stia', 'essendo', 'sarò', 'facesse', 'è', 'abbiano', 'tutto', 'quelli', 'fai', 'farai', 'dei', 'lei', 'avrai', 'il', 'nostre', 'sull', 'suoi', 'a', 'stava', 'su', 'nello', 'eri', 'fecero', 'staranno', 'facevano', 'farete', 'facesti', 'dalla', 'ad', 'sei', 'farò', 'nella', 'faceste', 'starai', 'dove', 'stiate', 'non', 'stettero', 'sono', 'gli', 'negl', 'quante', 'stanno', 'faremo', 'faremmo', 'sui', 'tu', 'che', 'foste', 'sia', 'stando', 'dell', 'ebbi', 'era', 'dov', 'avesti', 'perché', 'avevano', 'ai', 'dagli', 'avemmo', 'avuta', 'erano', 'mie', 'quello', 'avranno', 'avevi', 'saremmo', 'stavi', 'suo', 'alle', 'si', 'mia', 'questa', 'aveste', 'stiano', 'starebbe', 'i', 'abbiamo', 'starete', 'agli', 'dello', 'tuoi', 'farei', 'sulle', 'stavate', 'ed', 'nel', 'contro', 'facevi', 'sta', 'facevo', 'starebbero', 'nostri', 'quale', 'come', 'queste', 'avessi', 'sarà', 'dallo', 'avrebbero', 'di', 'ebbero', 'faceva', 'ci', 'allo', 'facevamo', 'hanno', 'stavamo', 'nelle', 'un', 'li', 'vostre', 'sullo', 'eravamo', 'stette', 'per', 'lo', 'dagl', 'l', 'avremo', 'ebbe', 'sarebbe', 'mio', 'avevo', 'se', 'tua', 'facessimo', 'le', 'facemmo', 'staremmo', 'dall', 'con', 'quanta', 'stetti', 'sugl', 'fanno', 'sugli', 'saresti', 'siano', 'faranno', 'quanto', 'ero', 'saremo', 'siamo', 'la', 'stessero', 'avrò', 'fui', 'fossero', 'dal', 'anche', 'stiamo', 'col', 'abbiate', 'sarai', 'avevate', 'lui', 'steste', 'in', 'stemmo', 'fummo', 'starei', 'chi', 'al', 'avessero', 'avremmo', 'avessimo', 'fosti', 'avesse', 'vostra', 'facevate', 'sul', 'avrei', 'fossi', 'nostro', 'miei', 'avute', 'sto', 'sarebbero', 'stareste', 'ho', 'mi', 'saranno', 'sue', 'hai', 'stavo', 'tra', 'quella'}
#
# List of stopwords in Kazakh:
# {'эй', 'морт', 'өз', 'сол', 'митың-митың', 'біздерге', 'сенің', 'менде', 'сенде', 'сіздермен', 'өзінің', 'япырмай', 'қорс', 'кірт', 'арс-ұрс', 'шек', 'жалт-жұлт', 'құрау-құрау', 'ырқ', 'осынау', 'өзіне', 'біреу', 'шаңқ', 'әйда', 'әукім', 'бұл', 'алайда', 'ей', 'айтпақшы', 'сарт-сұрт', 'ах', 'сондай', 'өзі', 'арс', 'гүрс', 'қайқаң-құйқаң', 'ие', 'мыңқ', 'әрқалай', 'әлдеқалай', 'бүгжең-бүгжең', 'бізбен', 'шақты', 'қаңғыр-күңгір', 'дегенмен', 'дейін', 'тырс', 'саған', 'себебі', 'батыр-бұтыр', 'ғана', 'ол', 'сыңқ', 'астапыралла', 'пай', 'сізбен', 'әрине', 'далаң-далаң', 'кә', 'желп', 'сіздер', 'қаңқ-құңқ', 'дүңк', 'маған', 'сайын', 'ғұрлым', 'кәне', 'сорап', 'моһ', 'ешбір', 'тағыда', 'олар', 'олардың', 'кейбір', 'сіздерден', 'қалт-қалт', 'бәрі', 'кәні', 'бірақ', 'кейбіреу', 'борт', 'мына', 'менімен', 'ербелең-ербелең', 'сонау', 'бұндай', 'шәйт', 'па', 'туралы', 'түге', 'сен', 'әлдекім', 'әй', 'қалт-құлт', 'әншейін', 'тәк', 'сіз', 'арсалаң-арсалаң', 'әрбір', 'қоса', 'шырт', 'сияқты', 'алатау', 'әттең', 'дәнеңе', 'уау', 'тағы', 'кәнеки', 'жалт-жалт', 'ойпырмай', 'жоқ', 'аһа', 'бойымен', 'әрқайсы', 'біздермен', 'қайсыбір', 'шамалы', 'ау', 'әркім', 'біздің', 'пішту', 'е', 'қош-қош', 'менен', 'пырс', 'әлденеше', 'осындай', 'өй', 'тек', 'мен', 'ештеме', 'былп', 'таман', 'масқарай', 'біздер', 'қана', 'мышы', 'шейін', 'саңқ', 'алақай', 'сенімен', 'онымен', 'қаралы', 'күшім', 'барқ', 'шаңқ-шаңқ', 'солай', 'ой', 'тарбаң-тарбаң', 'одан', 'ешқандай', 'анау', 'пай-пай', 'жуық', 'өзіме', 'әлдеқашан', 'әлдене', 'ешқайсы', 'арқылы', 'ыңқ', 'ыржың-тыржың', 'әйткенмен', 'үшін', 'паһ-паһ', 'оларға', 'дүрс', 'тарс', 'бізге', 'біз', 'уа', 'өйткені', 'әні', 'ырс', 'мынау', 'кейін', 'арнайы', 'онда', 'бізден', 'пішә', 'салаң-сұлаң', 'пфша', 'оһо', 'шаңқ-шұңқ', 'ана', 'қарай', 'сіздің', 'ешқашан', 'оның', 'ох', 'барша', 'қаңқ-қаңқ', 'сондықтан', 'менің', 'таңқ', 'ешкім', 'кәһ', 'сонымен', 'жалп', 'күңк', 'үйт', 'тыңқ', 'тарта', 'соң', 'сона', 'жаракімалла', 'бетер', 'күрт', 'ура', 'олармен', 'тарс-тұрс', 'таяу', 'алдақашан', 'қызараң-қызараң', 'эх', 'бүйт', 'арбаң-арбаң', 'я', 'ай', 'өзің', 'өзге', 'ал', 'маңқ', 'бері', 'шіркін', 'сенен', 'емес', 'осылай', 'біздерден', 'еш', 'құр', 'болп', 'қолп', 'оған', 'олардан', 'мәссаған', 'қап', 'уай', 'мұндай', 'сіздерге', 'әттегенай', 'құрау', 'қатар', 'салым', 'сіздердің', 'бар', 'әлдеқайдан', 'бірнеше', 'бүкіл', 'о', 'шіңк', 'сенен\tонан', 'сізге', 'барлық', 'ә', 'бойы', 'бірге', 'міне', 'өзім', 'әйтпесе', 'беу', 'бұрын', 'өзімнің', 'әрне', 'қыңқ', 'ірк', 'күллі', 'гөрі', 'сарт', 'әттеген-ай', 'түгел', 'сізден', 'бәрекелді', 'осы', 'ғұрлы', 'біздердің', 'бірдеме'}
#
# List of stopwords in Nepali:
# {'अर्थात्', 'प्रतेक', 'थियो', 'तर', 'कुनै', 'त्सैले', 'किनभने', 'तिर', 'बरु', 'चाहिए', 'पूर्व', 'छन्', 'देखेर', 'यथोचित', 'क्रमशः', 'चाहनुहुन्छ', 'आफ्नो', 'थिए', 'जे', 'जसलाई', 'देखिन्छ', 'लाई', 'चाले', 'लगभग', 'हुन', 'एउटै', 'यसो', 'सबै', 'आदि', 'त्सपछि', 'पटक', 'धेरै', 'गैर', 'को', 'कम से कम', 'गरौं', 'निम्न', 'यसबाहेक', 'जाहिर', 'पर्थ्यो', 'नै', 'यदि', 'देखि', 'गरि', 'लागि', 'तिनिहरुलाई', 'राखे', 'जब', 'जसमा', 'आए', 'सधै', 'पहिलो', 'तिनीहरू', 'भन्छन्', 'बीच', 'मात्र', 'प्लस', 'रही', 'अलग', 'जस्तै', 'चाहन्छु', 'राम्रो', 'पछिल्लो', 'हरे', 'यसरी', 'यद्यपि', 'भन्छु', 'भएको', 'निम्नानुसार', 'आत्म', 'जस्तो', 'उनको', 'हुन्छ', 'तेस्रो', 'यहाँ', 'यहाँसम्म', 'भने', 'अर्को', 'गर्छ', 'पक्कै', 'पहिल्यै', 'कसरी', 'अगाडी', 'तपाईको', 'दोस्रो', 'हो', 'कृपया', 'छु', 'केही', 'दिए', 'त्यो', 'तत्काल', 'गरेर', 'जस्तोसुकै', 'जसबाट', 'तथा', 'का', 'कोही', 'ओठ', 'अरु', 'भित्र', 'अरुलाई', 'बारे', 'नि', 'बिशेष', 'चार', 'छौं', 'तुरुन्तै', 'देखे', 'संग', 'बीचमा', 'रहेको', 'पक्का', 'संगै', 'सोही', 'यो', 'ले', 'तपाई', 'आयो', 'जबकि', 'नजिकै', 'छैन', 'सो', 'नत्र', 'तापनी', 'सही', 'छ', 'उदाहरण', 'हुने', 'त्यहाँ', 'कतै', 'नयाँ', 'भित्री', 'न', 'मेरो', 'साथ', 'पाँच', 'गरेको', 'जसले', 'फेरी', 'साँच्चै', 'अब', 'तिनीहरुको', 'साथै', 'त', 'गर्न', 'जुन', 'रूप', 'अन्यत्र', 'अनुसार', 'हरेक', 'औं', 'एकदम', 'बने', 'आफूलाई', 'गर्छु', 'माथि', 'यस', 'देखियो', 'अन्य', 'यस्तो', 'कसैले', 'आफ्नै', 'गर्ने', 'कहाँबाट', 'एक', 'यी', 'जसको', 'गर्दै', 'आफू', 'कहिलेकाहीं', 'तेस्कारण', 'सम्भव', 'सायद', 'तिनी', 'शायद', 'भन्', 'म', 'थिएन', 'भन्दा', 'अक्सर', 'यसको', 'उप', 'सारा', 'ठीक', 'यसपछि', 'या', 'बाहिर', 'अझै', 'बाहेक', 'कि', 'र', 'ती', 'उहालाई', 'दिनुभएको', 'राख्छ', 'तीन', 'सात', 'सम्म', 'हुन्', 'गरी', 'गर्नुपर्छ', 'गरेका', 'के', 'जान', 'तदनुसार', 'अर्थात', 'प्रति', 'निम्ति', 'पछि', 'मलाई', 'कसै', 'भन', 'वरीपरी', 'पनि', 'आजको', 'गर्नु', 'उनले', 'अन्यथा', 'जो', 'दुई', 'सक्छ', 'स्पष्ट', 'गए', 'जताततै', 'जहाँ', 'भन्ने', 'वास्तवमा', 'मुख्य', 'पाँचौं', 'तल', 'नौ', 'छू', 'भर', 'सबैलाई', 'पर्याप्त', 'दिनुहुन्छ', 'पहिले', 'पर्छ', 'रहेका', 'बिरुद्ध', 'यति', 'अन्तर्गत', 'मा', 'गयौ', 'किन', 'सट्टा', 'भए', 'समय', 'देखेको', 'भन्नुभयो', 'कुरा', 'निर्दिष्ट', 'तिमी'}
#
# List of stopwords in Norwegian:
# {'no', 'vil', 'mellom', 'kvarhelst', 'sånn', 'hennes', 'av', 'fra', 'for', 'disse', 'vi', 'dykkar', 'begge', 'vart', 'før', 'når', 'hva', 'korso', 'deg', 'skulle', 'siden', 'på', 'til', 'um', 'ville', 'deres', 'kan', 'din', 'hvis', 'og', 'ut', 'mange', 'ha', 'honom', 'hoss', 'ved', 'hvorfor', 'meget', 'korleis', 'så', 'et', 'om', 'at', 'ein', 'eg', 'også', 'deires', 'uten', 'selv', 'ikkje', 'da', 'hvilken', 'hadde', 'hvor', 'er', 'oss', 'slik', 'kun', 'vært', 'være', 'har', 'verte', 'han', 'kven', 'min', 'ble', 'me', 'noen', 'dei', 'sidan', 'dem', 'skal', 'dere', 'hver', 'kva', 'blei', 'nokre', 'då', 'dykk', 'so', 'varte', 'vore', 'deim', 'ja', 'å', 'somt', 'hans', 'blir', 'vår', 'kvifor', 'sia', 'somme', 'kvi', 'sjøl', 'eit', 'ingi', 'meg', 'henne', 'hossen', 'vors', 'inn', 'mine', 'alle', 'ditt', 'inni', 'si', 'etter', 'kvar', 'jeg', 'både', 'kom', 'i', 'ingen', 'fordi', 'vere', 'her', 'en', 'de', 'mot', 'seg', 'elles', 'sine', 'nå', 'noko', 'mykje', 'di', 'upp', 'hjå', 'eitt', 'hvilke', 'dette', 'ikke', 'kunne', 'bli', 'den', 'eller', 'båe', 'blitt', 'deira', 'hun', 'nokon', 'hvordan', 'med', 'noe', 'ett', 'over', 'hennar', 'inkje', 'men', 'du', 'som', 'denne', 'der', 'vort', 'det', 'hvem', 'nokor', 'opp', 'medan', 'hoe', 'ned', 'man', 'noka', 'samme', 'ho', 'mi', 'enn', 'mitt', 'sitt', 'sin', 'var', 'bare'}
#
# List of stopwords in Portuguese:
# {'houvemos', 'tem', 'tivermos', 'à', 'dele', 'no', 'nosso', 'quem', 'nem', 'houverão', 'o', 'os', 'hajamos', 'minha', 'nossas', 'elas', 'aquilo', 'for', 'formos', 'minhas', 'as', 'houverei', 'serão', 'por', 'estavam', 'nos', 'sua', 'tinha', 'do', 'estiver', 'quando', 'sejam', 'será', 'somos', 'ser', 'teve', 'tiverem', 'um', 'teus', 'eles', 'teríamos', 'tivessem', 'ao', 'eu', 'esse', 'aquelas', 'tenham', 'esses', 'já', 'na', 'sem', 'tivera', 'haver', 'houvesse', 'estiverem', 'fôramos', 'teria', 'aquela', 'vocês', 'aqueles', 'ou', 'estamos', 'em', 'te', 'da', 'este', 'e', 'está', 'hei', 'estejam', 'terei', 'terão', 'seria', 'fosse', 'esta', 'temos', 'seríamos', 'ele', 'dos', 'fora', 'foi', 'pelas', 'me', 'estivesse', 'estas', 'para', 'dela', 'é', 'aquele', 'meus', 'vos', 'com', 'tivéramos', 'a', 'nós', 'lhe', 'teriam', 'hão', 'das', 'você', 'tinham', 'tenhamos', 'teremos', 'seus', 'sou', 'deles', 'teu', 'tu', 'às', 'estive', 'era', 'hajam', 'isto', 'houveríamos', 'pelo', 'estejamos', 'nossos', 'também', 'nas', 'estivéramos', 'houverem', 'pelos', 'seja', 'houveria', 'só', 'estivera', 'houvéramos', 'isso', 'estou', 'de', 'mas', 'pela', 'seremos', 'suas', 'foram', 'tenho', 'estão', 'estes', 'entre', 'tivesse', 'haja', 'qual', 'lhes', 'estivéssemos', 'houveriam', 'sejamos', 'esteja', 'que', 'houvera', 'não', 'tuas', 'estivessem', 'houve', 'meu', 'nossa', 'se', 'tive', 'mais', 'tua', 'estar', 'fôssemos', 'essas', 'tivemos', 'seu', 'houver', 'fossem', 'tínhamos', 'numa', 'fui', 'tivéssemos', 'depois', 'são', 'houvéssemos', 'forem', 'tém', 'essa', 'houvessem', 'mesmo', 'esteve', 'estivermos', 'aos', 'estávamos', 'houveremos', 'estivemos', 'tenha', 'tiver', 'estiveram', 'fomos', 'serei', 'houverá', 'há', 'ela', 'estava', 'muito', 'como', 'houvermos', 'éramos', 'seriam', 'tiveram', 'eram', 'havemos', 'até', 'houveram', 'terá', 'num', 'delas', 'uma'}
#
# List of stopwords in Romanian:
# {'or', 'o', 'vostru', 'dar', 'vi', 'sale', 'acea', 'mei', 'ului', 'din', 'ma', 'acei', 'voştri', 'avea', 'ăsta', 'imi', 'său', 'altcineva', 'noştri', 'avut', 'el', 'îi', 'este', 'desi', 'oricare', 'treilea', 'alta', 'voi', 'sus', 'după', 'cind', 'dau', 'orice', 'tăi', 'poate', 'vă', 'voastră', 'unei', 'ul', 'cărui', 'cu', 'tot', 'fata', 'mele', 'săi', 'aţi', 'drept', 'fara', 'isi', 'mie', 'zi', 'aveţi', 'mereu', 'ceva', 'sub', 'nici', 'oricând', 'mîine', 'au', 'atitia', 'dintre', 'ii', 'sunteţi', 'altceva', 'mâine', 'aceste', 'avem', 'sa-ti', 'ba', 'vreun', 'această', 'puţin', 'ia', 'oriunde', 'totul', 'suntem', 'pentru', 'atatia', 'incit', 'acestui', 'patru', 'acela', 'fii', 'cîtva', 'mod', 'atitea', 'u', 'ar', 'astfel', 'şi', 'care', 'ala', 'ne', 'numai', 'către', 'as', 'acelea', 'noi', 'iti', 'fiu', 'ce', 'ta', 'cel', 't', 'nostru', 'asupra', 'câtva', 'inapoi', 'aceasta', 'atatea', 'te', 'apoi', 'da', 'treia', 'alte', 'unuia', 'printr-', 'atit', 'despre', 'două', 'unii', 'prima', 'ceea', 'doar', 'peste', 'câţi', 'aceştia', 'il', 'ceilalti', 'cît', 'prea', 'pot', 'ăla', 'lângă', 'ţie', 'altii', 'tu', 'sunt', 'ai', 'cînd', 'mine', 'si', 'i', 'fel', 'niste', 'uneia', 'uneori', 'cat', 'dintr-', 'deci', 'unora', 'vreo', 'ni', 'să', 'li', 'ţi', 'va', 'dintr', 'pic', 'multi', 'ăştia', 'nu', 'cea', 'atita', 'tău', 'căci', 'iar', 'la', 'cum', 'parca', 'inca', 'carora', 'lui', 'altfel', 'al', 'unele', 'fost', 'cineva', 'decit', 'fi', 'citiva', 'toţi', 'daca', 'zice', 'sint', 'deja', 'alt', 'puţină', 'cui', 'cumva', 'cand', 'sau', 'putini', 'adica', 'caruia', 'undeva', 'sa-mi', 'acestia', 'mult', 'spre', 'eu', 'fie', 'acestea', 'acestei', 'face', 'îmi', 'ti', 'toată', 'm', 'acele', 'aceşti', 'abia', 'oricât', 'e', 'ati', 'mai', 'inainte', 'catre', 'ele', 'atunci', 'îţi', 'fiţi', 'trei', 'oricînd', 'multa', 'deasupra', 'intre', 'oricine', 'cîţi', 'era', 'v', 'pînă', 'spate', 'prin', 'chiar', 'noastră', 'cine', 'altul', 'atat', 'vouă', 'nostri', 'căror', 'vom', 'ci', 'intr', 'dată', 'am', 'un', 'multă', 'fără', 'sai', 'pina', 'celor', 'cei', 'careia', 'se', 'le', 'acel', 'sa', 'nimic', 'aici', 'in', 'unul', 'puţina', 'acest', 'toti', 'citi', 'cele', 'până', 'unde', 'totuşi', 'unu', 'ălea', 'ca', 'tocmai', 'dă', 'foarte', 'oricum', 'doilea', 'că', 'totusi', 'ei', 'aceeasi', 'nouă', 'multe', 'atata', 'noua', 'câte', 'aş', 'tale', 'cit', 'citeva', 'toata', 'una', 'acesta', 'primul', 'eşti', 'aceea', 'are', 'cite', 'dat', 'a', 'tine', 'acelasi', 'pe', 'deşi', 'fim', 'cărei', 'aia', 'cam', 'tuturor', 'aibă', 'lîngă', 'ale', 'fiecare', 'cât', 'insa', 'de', 'sintem', 'asta', 'oricît', 'cita', 'toate', 'astea', 'ori', 'asa', 'voastre', 'nimeni', 'mea', 'unor', 'aceia', 'cîte', 'doi', 'ea', 'nou', 'alti', 'meu', 'în', 'anume', 'alea', 'dacă', 'îl', 'dupa', 'vor', 'noastre', 'unui', 'mulţi', 'lor', 'pai', 'nişte', 'mă', 'ăstea', 'mi', 'eram', 'atare', 'patra'}
#
# List of stopwords in Russian:
# {'не', 'разве', 'тебя', 'со', 'его', 'мой', 'вот', 'если', 'же', 'два', 'был', 'сейчас', 'ей', 'здесь', 'только', 'три', 'тоже', 'над', 'ней', 'один', 'где', 'даже', 'него', 'наконец', 'можно', 'быть', 'было', 'надо', 'перед', 'через', 'почти', 'вам', 'вас', 'есть', 'тут', 'от', 'они', 'об', 'них', 'лучше', 'впрочем', 'себя', 'без', 'за', 'под', 'бы', 'она', 'тот', 'в', 'этого', 'там', 'нет', 'им', 'сам', 'будто', 'хорошо', 'какой', 'их', 'во', 'моя', 'куда', 'чтобы', 'того', 'меня', 'с', 'а', 'хоть', 'к', 'вдруг', 'иногда', 'всех', 'зачем', 'то', 'может', 'себе', 'нас', 'уж', 'раз', 'эти', 'ли', 'и', 'как', 'опять', 'чего', 'более', 'тем', 'да', 'никогда', 'другой', 'между', 'ему', 'ну', 'кто', 'всю', 'из', 'или', 'ее', 'ж', 'мы', 'до', 'всего', 'при', 'много', 'свою', 'нее', 'ты', 'какая', 'этот', 'эту', 'этом', 'у', 'были', 'все', 'ним', 'больше', 'потому', 'нибудь', 'ничего', 'ни', 'этой', 'когда', 'чуть', 'всегда', 'конечно', 'мне', 'уже', 'что', 'я', 'была', 'вы', 'ведь', 'теперь', 'чтоб', 'для', 'после', 'про', 'но', 'он', 'такой', 'совсем', 'чем', 'будет', 'так', 'о', 'по', 'еще', 'на', 'нельзя', 'тогда', 'том', 'потом'}
#
# List of stopwords in Spanish:
# {'o', 'habremos', 'serían', 'sentido', 'hubiste', 'estarían', 'tuvo', 'ellos', 'estuvieras', 'contra', 'estados', 'habrán', 'habrías', 'ya', 'tenéis', 'hubieseis', 'nuestros', 'ante', 'tuviésemos', 'fueron', 'muchos', 'ha', 'tendría', 'estuvieron', 'el', 'vuestro', 'este', 'está', 'seamos', 'fueran', 'sus', 'poco', 'estuviese', 'para', 'vosotras', 'ellas', 'estabas', 'tuvimos', 'mías', 'están', 'tendré', 'seré', 'fue', 'tenidos', 'tuyos', 'hayáis', 'estando', 'vuestra', 'es', 'tendrán', 'tuvieses', 'tuviese', 'habían', 'hayas', 'tenía', 'muy', 'tuviesen', 'esto', 'habidos', 'tenido', 'fuese', 'nada', 'tanto', 'con', 'tuve', 'algo', 'seríais', 'tengan', 'habéis', 'sentida', 'tuviste', 'éramos', 'sí', 'no', 'haya', 'hube', 'nuestra', 'estéis', 'quienes', 'por', 'somos', 'esa', 'otra', 'estuve', 'mía', 'estaba', 'hubiera', 'del', 'cuando', 'seas', 'te', 'hubiesen', 'estabais', 'durante', 'esté', 'estuviéramos', 'él', 'mío', 'habías', 'porque', 'ese', 'fueses', 'habré', 'habidas', 'estarán', 'tengáis', 'hubieran', 'estará', 'estuvisteis', 'estuviesen', 'algunos', 'hubieras', 'tu', 'suya', 'antes', 'estáis', 'seáis', 'fuesen', 'pero', 'estés', 'esas', 'hubo', 'sintiendo', 'había', 'tenida', 'otro', 'míos', 'teniendo', 'estado', 'hubisteis', 'yo', 'tendríamos', 'hubimos', 'habría', 'ni', 'eres', 'tenidas', 'tuvieseis', 'estaban', 'hubiese', 'fuéramos', 'tuya', 'estuvieses', 'hayan', 'sería', 'estar', 'todo', 'unos', 'sois', 'habida', 'estaremos', 'nosotras', 'la', 'tuvieras', 'habríais', 'al', 'tuvieron', 'he', 'erais', 'habrían', 'hasta', 'fuerais', 'estoy', 'estos', 'uno', 'os', 'has', 'serías', 'fuésemos', 'habido', 'tenga', 'estábamos', 'eso', 'estuvierais', 'tenemos', 'hubiéramos', 'mis', 'tendrías', 'ti', 'estadas', 'e', 'hemos', 'estaré', 'hubieses', 'han', 'estas', 'estuviste', 'seréis', 'siente', 'su', 'estuviésemos', 'estaríamos', 'les', 'sean', 'fuera', 'vuestros', 'fuimos', 'sea', 'era', 'mí', 'las', 'otras', 'habrá', 'habiendo', 'estemos', 'en', 'estás', 'nuestras', 'seremos', 'sentid', 'tendremos', 'entre', 'esos', 'un', 'desde', 'tendrás', 'tendréis', 'tuvisteis', 'tienes', 'tengo', 'hubieron', 'se', 'le', 'hubiésemos', 'otros', 'sentidas', 'nuestro', 'fui', 'tuviera', 'tiene', 'también', 'mucho', 'estaréis', 'tendrá', 'habréis', 'tendrían', 'más', 'estuvo', 'estuviera', 'suyo', 'sin', 'hubierais', 'todos', 'estad', 'fueras', 'hayamos', 'algunas', 'teníamos', 'habíamos', 'nos', 'será', 'serán', 'suyos', 'habríamos', 'habrás', 'eran', 'tuvierais', 'tengamos', 'sobre', 'estén', 'cual', 'estamos', 'una', 'sentidos', 'ella', 'soy', 'esta', 'seríamos', 'y', 'tengas', 'fuisteis', 'serás', 'me', 'hay', 'a', 'tuyas', 'estuvieseis', 'estuvimos', 'estarías', 'donde', 'estaríais', 'tuviéramos', 'tus', 'quien', 'tenías', 'vosotros', 'estada', 'de', 'tienen', 'tenían', 'vuestras', 'nosotros', 'estarás', 'eras', 'estuvieran', 'tendríais', 'que', 'suyas', 'tuvieran', 'fuiste', 'teníais', 'lo', 'los', 'fueseis', 'tened', 'tuyo', 'son', 'habíais', 'tú', 'qué', 'estaría', 'mi', 'como'}
#
# List of stopwords in Swedish:
# {'blev', 'vid', 'än', 'från', 'dessa', 'hennes', 'åt', 'av', 'dina', 'vi', 'vart', 'skulle', 'vars', 'varje', 'på', 'varit', 'kan', 'denna', 'din', 'varför', 'ut', 'själv', 'ha', 'hon', 'honom', 'inte', 'där', 'så', 'inom', 'om', 'alla', 'sedan', 'er', 'oss', 'vårt', 'någon', 'några', 'har', 'han', 'sitta', 'min', 'sådant', 'till', 'vem', 'dem', 'utan', 'hade', 'då', 'detta', 'hans', 'blir', 'ju', 'vår', 'våra', 'och', 'vilket', 'era', 'när', 'henne', 'ditt', 'i', 'ingen', 'för', 'ej', 'en', 'de', 'sig', 'mot', 'sådana', 'vilka', 'dig', 'ni', 'mycket', 'mina', 'upp', 'sina', 'vilkas', 'att', 'dess', 'bli', 'samma', 'ert', 'sådan', 'nu', 'den', 'eller', 'mig', 'blivit', 'med', 'är', 'ett', 'men', 'du', 'hur', 'som', 'deras', 'vad', 'allt', 'efter', 'här', 'under', 'vilken', 'det', 'mellan', 'något', 'över', 'jag', 'man', 'icke', 'vara', 'kunde', 'mitt', 'sin', 'var'}
#
# List of stopwords in Turkish:
# {'için', 'niçin', 'defa', 'ise', 'bazı', 'o', 'hem', 'da', 'daha', 'ne', 'siz', 'aslında', 'hepsi', 'çok', 'kez', 'neden', 'şey', 'nereye', 'niye', 've', 'şu', 'acaba', 'belki', 'bu', 'eğer', 'hep', 'birkaç', 'her', 'en', 'diye', 'de', 'ya', 'biz', 'kim', 'mı', 'ile', 'nerede', 'tüm', 'yani', 'hiç', 'mu', 'nerde', 'birşey', 'az', 'ama', 'mü', 'veya', 'gibi', 'nasıl', 'sanki', 'biri', 'ki', 'çünkü'}

# %% [markdown]
# ### Write a Python NLTK program to remove stop words from a given text.

# %%
# In computing, stop words are words which are filtered out before or after processing of natural language data (text). Though 
# "stop words" usually refers to the most common words in a language, there is no single universal list of stop words used by 
# all natural language processing tools, and indeed not all tools even use such a list. Some tools specifically avoid removing 
# these stop words to support phrase search.
# Any group of words can be chosen as the stop words for a given purpose. For some search engines, these are some of the most 
# common, short function words, such as the, is, at, which, and on. In this case, stop words can cause problems when searching
# for phrases that include them, particularly in names such as "The Who", "The The", or "Take That". Other search engines
# remove some of the most common words-including lexical words, such as "want"-from a query in order to improve performance.

from nltk.corpus import stopwords
stoplist = stopwords.words('english')
text = '''
In computing, stop words are words which are filtered out before or after 
processing of natural language data (text). Though "stop words" usually 
refers to the most common words in a language, there is no single universal 
list of stop words used by all natural language processing tools, and 
indeed not all tools even use such a list. Some tools specifically avoid 
removing these stop words to support phrase search.
'''
print("\nOriginal string:")
print(text)
clean_word_list = [word for word in text.split() if word not in stoplist]
print("\nAfter removing stop words from the said text:")
print(clean_word_list)
# Out:
# Original string:
#
# In computing, stop words are words which are filtered out before or after
# processing of natural language data (text). Though "stop words" usually
# refers to the most common words in a language, there is no single universal
# list of stop words used by all natural language processing tools, and
# indeed not all tools even use such a list. Some tools specifically avoid
# removing these stop words to support phrase search.
#
#
# After removing stop words from the said text:
# ['In', 'computing,', 'stop', 'words', 'words', 'filtered', 'processing', 'natural', 'language', 'data', '(text).', 'Though', '"stop', 'words"', 'usually', 'refers', 'common', 'words', 'language,', 'single', 'universal', 'list', 'stop', 'words', 'used', 'natural', 'language', 'processing', 'tools,', 'indeed', 'tools', 'even', 'use', 'list.', 'Some', 'tools', 'specifically', 'avoid', 'removing', 'stop', 'words', 'support', 'phrase', 'search.']

# %% [markdown]
# ###  Write a Python NLTK program to omit some given stop words from the stopwords list.

# %%
import nltk
from nltk.corpus import stopwords
result = set(stopwords.words('english'))
print("List of stopwords in English:")
print(result)
print("\nOmit - 'again', 'once' and 'from':")
stop_words = set(stopwords.words('english')) - set(['again', 'once', 'from'])
print("\nList of fresh stopwords in English:")
print (stop_words)
# Out:
# List of stopwords in English:
# {'didn', 'had', 'yours', 'or', 'no', 'should', "wouldn't", 'o', 'has', 'all', "couldn't", 'shan', "shouldn't", 'once', 'ourselves', 'for', 'd', 'most', 'him', 'itself', 'as', 'off', 'too', "hasn't", 'on', 'do', 'his', 'being', 'having', 'about', 'have', 'be', 'own', 'themselves', 'of', 'll', 'not', 'who', 'those', 't', 'some', 'ma', 'an', 'hadn', 'how', 'hasn', 'mightn', 'at', 'm', "wasn't", 'nor', 'whom', "don't", 'was', 'above', 'himself', 'yourself', 'because', 'y', 'its', 'through', 'are', 'me', "hadn't", 'your', 'while', 'does', 'again', 'myself', "weren't", 'a', 'during', 'is', 'and', 'doing', 'more', 'between', 'needn', 'so', 'than', 'won', "doesn't", "it's", 'below', 'out', 'isn', "mustn't", 'few', 'yourselves', 've', "she's", 'you', 'hers', 'such', 'mustn', 'from', 'did', 'doesn', 'both', "aren't", 'here', 'i', 'there', "needn't", 'now', 'her', 'if', 'aren', 'were', 'very', "you'd", 'down', "isn't", 'any', "you're", 'am', 'by', "won't", 'theirs', 'she', 'other', 'herself', 'then', 'them', 'what', 'we', 'after', 'but', 'couldn', 're', 'it', 'wouldn', 'their', "mightn't", 'can', 'shouldn', 'only', 'our', 'the', 'over', 'ours', 'don', 'against', 'why', 'same', "you've", 'which', 'in', 'to', 'will', 'been', 'under', "didn't", "you'll", 'where', "haven't", 'he', 'up', 'just', 'before', 'with', "shan't", 'until', 'further', 'that', 'when', 'weren', "should've", 'haven', 'this', 'ain', 'they', "that'll", 'each', 's', 'these', 'my', 'wasn', 'into'}
#
# Omit - 'again', 'once' and 'from':
#
# List of fresh stopwords in English:
# {'didn', 'had', 'yours', 'or', 'no', 'should', "wouldn't", 'o', 'has', 'all', "couldn't", 'shan', "shouldn't", 'ourselves', 'for', 'd', 'most', 'him', 'itself', 'as', 'off', 'too', "hasn't", 'on', 'do', 'his', 'being', 'having', 'about', 'have', 'be', 'own', 'themselves', 'of', 'll', 'not', 'who', 'those', 't', 'some', 'ma', 'an', 'hadn', 'how', 'hasn', 'mightn', 'at', 'm', "wasn't", 'nor', 'whom', "don't", 'was', 'above', 'himself', 'yourself', 'because', 'y', 'its', 'through', 'are', 'me', "hadn't", 'your', 'while', 'does', 'myself', "weren't", 'a', 'during', 'is', 'and', 'doing', 'more', 'between', 'needn', 'so', 'than', 'won', "doesn't", "it's", 'below', 'out', 'isn', "mustn't", 'few', 'yourselves', 've', "she's", 'you', 'hers', 'such', 'mustn', 'did', 'doesn', 'both', "aren't", 'here', 'i', 'there', "needn't", 'now', 'her', 'if', 'aren', 'were', 'very', "you'd", 'down', "isn't", 'any', "you're", 'am', 'by', "won't", 'theirs', 'she', 'other', 'herself', 'then', 'them', 'what', 'we', 'after', 'but', 'couldn', 're', 'it', 'wouldn', 'their', "mightn't", 'can', 'shouldn', 'only', 'our', 'the', 'over', 'ours', 'don', 'against', 'why', 'same', "you've", 'which', 'in', 'to', 'will', 'been', 'under', "didn't", "you'll", 'where', "haven't", 'he', 'up', 'just', 'before', 'with', "shan't", 'until', 'further', 'that', 'when', 'weren', "should've", 'haven', 'this', 'ain', 'they', "that'll", 'each', 's', 'these', 'my', 'wasn', 'into'}

# %%
# C:\Users\djoshi\Anaconda3\Lib\site-packages\nltk
import nltk
print(nltk.__file__)
# Out:
# C:\Users\djoshi\Anaconda3\lib\site-packages\nltk\__init__.py

# %%
# path ='C:/Users/djoshi/Anaconda3/Lib/site-packages/nltk/corpus/reader'

# %% [markdown]
# ### Write a Python NLTK program to find the definition and examples of a given word using WordNet.
# WordNet is a lexical database for the English language. It groups English words into sets of synonyms called synsets, provides short definitions and usage examples, and records a number of relations among these synonym sets or their members. WordNet can thus be seen as a combination of dictionary and thesaurus. While it is accessible to human users via a web browser, its primary use is in automatic text analysis and artificial intelligence applications. The database and software tools have been released under a BSD style license and are freely available for download from the WordNet website. Both the lexicographic data (lexicographer files) and the compiler (called grind) for producing the distributed database are available.

# %%
from nltk.corpus import wordnet 
syns = wordnet.synsets("fight")
print(syns)
print("\nDefination of the said word:")
print(syns[0].definition())
print("\nExamples of the word in use::")
print(syns[0].examples())
# Out:
# [Synset('battle.n.01'), Synset('fight.n.02'), Synset('competitiveness.n.01'), Synset('fight.n.04'), Synset('fight.n.05'), Synset('contend.v.06'), Synset('fight.v.02'), Synset('fight.v.03'), Synset('crusade.v.01')]
#
# Defination of the said word:
# a hostile meeting of opposing military forces in the course of a war
#
# Examples of the word in use::
# ['Grant won a decisive victory in the battle of Chickamauga', 'he lost his romantic ideas about war when he got into a real engagement']

# %% [markdown]
# ### Write a Python NLTK program to find the sets of synonyms and antonyms of a given word
# https://stackoverflow.com/questions/59355529/is-there-any-order-in-wordnets-synsets

# %%
wordnet.synsets("end")
# Out:
# [Synset('end.n.01'),
#  Synset('end.n.02'),
#  Synset('end.n.03'),
#  Synset('goal.n.01'),
#  Synset('end.n.05'),
#  Synset('end.n.06'),
#  Synset('end.n.07'),
#  Synset('end.n.08'),
#  Synset('end.n.09'),
#  Synset('end.n.10'),
#  Synset('end.n.11'),
#  Synset('conclusion.n.08'),
#  Synset('end.n.13'),
#  Synset('end.n.14'),
#  Synset('end.v.01'),
#  Synset('end.v.02'),
#  Synset('end.v.03'),
#  Synset('end.v.04')]

# %%
from nltk.corpus import wordnet
synonyms = []
antonyms = []

for syn in wordnet.synsets("end"):
#     print(syn)
    for l in syn.lemmas():
#         print(l)
        synonyms.append(l.name())
        if l.antonyms():
#             print(l.antonyms())
            antonyms.append(l.antonyms()[0].name())
            
print("\nSet of synonyms of the said word:")
print(set(synonyms))
print("\nSet of antonyms of the said word:")
print(set(antonyms))
# Out:
# Set of synonyms of the said word:
# {'closing', 'remnant', 'final_stage', 'stop', 'finish', 'cease', 'death', 'destruction', 'oddment', 'terminate', 'remainder', 'end', 'conclusion', 'ending', 'close', 'goal', 'last', 'terminal'}
#
# Set of antonyms of the said word:
# {'beginning', 'begin'}

# %%
from nltk.corpus import wordnet
print("\nComparing ship anb boat:")
n1 = wordnet.synset('ship.n.01')
n2 = wordnet.synset('boat.n.01')
print(n1.wup_similarity(n2))

print("\nComparing bus anb boat:")
n1 = wordnet.synset('bus.n.01')
n2 = wordnet.synset('boat.n.01')
print(n1.wup_similarity(n2))

print("\nComparing red anb greed:")
n1 = wordnet.synset('red.n.01')
n2 = wordnet.synset('green.n.01')
print(n1.wup_similarity(n2))
# Out:
# Comparing ship anb boat:
# 0.9090909090909091
#
# Comparing bus anb boat:
# 0.7
#
# Comparing red anb greed:
# 0.875

# %% [markdown]
# ## Construct a parse tree for the sentence using CFG rules
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Ans:
# https://www.youtube.com/watch?v=ovenwMD4U9Y
#
# (Ignore hand)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Construct top down and bottom up parse tree for the sentence using CFG rules
# ![image.png](attachment:image.png)

# %% [markdown]
# Ans
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
